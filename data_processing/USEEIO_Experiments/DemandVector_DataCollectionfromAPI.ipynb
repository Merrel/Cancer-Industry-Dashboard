# %%
#BASE URL AND KEY
#Use the requests library
import csv
import requests as r
import pandas as pd
import zipfile, io
import os

# %%
import pathlib

# Set a relative location to save the data from the request
repo_dir = pathlib.Path().cwd().parent
raw_data_dir = repo_dir / 'data_raw'

if not raw_data_dir.exists():
    raw_data_dir.mkdir(parents=True)

valueAdded_data_dir = raw_data_dir / 'ValueAdded'
if not valueAdded_data_dir.exists():
    valueAdded_data_dir.mkdir(parents=True)

# %%
#combined version for all years->"https://apps.bea.gov/industry/xls/underlying-estimates/GDPbyInd_VA_Components_1998-2018.xlsx"
#summary level per year->"https://apps.bea.gov/iTable/iTable.cfm?reqid=52&step=102&isuri=1&table_list=4&aggregation=sum"
#more aggregated.less columns->"https://apps.bea.gov/iTable/iTable.cfm?reqid=52&step=102&isuri=1&table_list=4&aggregation=sum"
response = r.get(url)
response = r.get(url)
file=open(valueAdded_data_dir/ f"valueAdded.xlsx", 'wb')
file.write(response.content)
file.close()
pd=pd.read_excel(open(valueAdded_data_dir/ f"valueAdded.xlsx", 'rb'),sheet_name='Components of VA')  
pd
# Out:
#             Cautionary note on the use of these data --      Unnamed: 1  \
# 0     These data include detailed estimates underlyi...             NaN
# 1                                                   NaN             NaN
# 2                                                 Code   Industry Title
# 3                     Value added (Millions of dollars)             NaN
# 4                                                    VA  All industries
# ...                                                 ...             ...
# 1211                                                NaN             NaN
# 1212                                                NaN             NaN
# 1213                                                NaN             NaN
# 1214  1.  Consists of agriculture, forestry, fishing...             NaN
# 1215  2.  Consists of utilities; wholesale trade; re...             NaN
#
#      Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# ...
