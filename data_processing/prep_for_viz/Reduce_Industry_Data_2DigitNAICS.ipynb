# %%
import pathlib
import pandas as pd
import numpy as np
import swifter
from tqdm import tqdm

from itertools import *

# %% [markdown]
# ### Goal: Process Industry Data Data --> .tsv for choropleth
#
# Current US choropleth example takes .tsv with the following format:
#
# ```
# id	rate
# 01001	5.1
# 01003	4.9
# 01005	8.6
# 01007	6.2
# ```
#
# where id is the county FIPS and rate is some value for coloring the choropleth

# %%
# Helper Functions
def fips_to_str(fips):
    fips_str = str(int(fips))

    while len(fips_str) < 5:
        fips_str = '0' + fips_str

    return fips_str


def extract_state_fips(fips_str):
    return int(fips_str[0:2])


def contains_3digit_naics(row):
    '''return True if any of the relevant naics is a three digit naic'''
    naics_list = row['relevant_naics'].replace(' ', '').strip('[]').split(',')
    check = any([len(naic)==3 for naic in naics_list])
    return check

# %%
base_dir = pathlib.Path.cwd()

# Load list of all county fips
county_fips_file = base_dir.parent.parent / 'data_raw' / 'counties_fips.csv'
counties = pd.read_csv(county_fips_file)
counties['fips_str'] = counties.FIPS.apply(fips_to_str)

# Load the cancer incidence data
data_dir = base_dir.parent.parent / 'data_clean' 

industry_data_csv = data_dir / 'indicators_per-industry_per-county.csv'

# Load ALL incidence rate data to dataframe
df = pd.read_csv(industry_data_csv)
df['fips_str'] = df['fips'].apply(fips_to_str)

# df3 = df[df.apply(contains_3digit_naics, axis=1)]

# df3.head()

# df = df.loc[0:10000, :]
# df.shape

# %%
df.head()
# Out:
#    Unnamed: 0  fips  county                    name industry_code  \
# 0           0  8001       1  Adams County, Colorado        113000
# 1           1  8001       1  Adams County, Colorado        115000
# 2           2  8001       1  Adams County, Colorado        211000
# 3           3  8001       1  Adams County, Colorado        2122a0
# 4           4  8001       1  Adams County, Colorado        212310
#
#                             industry_detail         relevant_naics  year  \
# 0            timber and raw forest products                  [113]  2012
# 1          agriculture and forestry support                  [115]  2012
# 2                     unrefined oil and gas                  [211]  2012
# 3  iron, gold, silver, and other metal ores  [21221, 21222, 21229]  2012
# 4                         dimensional stone                [21231]  2012
#
#    payann  estab  ...  MINE       MSW  NREN      OZON      PEST      REN  \
# 0       0      1  ...   0.0  0.000000   0.0  0.000000  0.000000  0.00000
# 1     290      6  ...   0.0  3.405586   0.0  0.000183  0.008769  0.95877
# 2       0      6  ...   0.0  0.000000   0.0  0.000000  0.000000  0.00000
# 3       0      1  ...   0.0  0.000000   0.0  0.000000  0.000000  0.00000
# 4       0      4  ...   0.0  0.000000   0.0  0.000000  0.000000  0.00000
#
#        SMOG        VADD       WATR  fips_str
# 0  0.000000    0.000000   0.000000     08001
# 1  2.011564  211.423463  15.653502     08001
# 2  0.000000    0.000000   0.000000     08001
# 3  0.000000    0.000000   0.000000     08001
# 4  0.000000    0.000000   0.000000     08001
#
# [5 rows x 36 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'fips', 'county', 'name', 'industry_code',
#        'industry_detail', 'relevant_naics', 'year', 'payann', 'estab', 'emp',
#        'ACID', 'ENRG', 'ETOX', 'EUTR', 'FOOD', 'GCC', 'HAPS', 'HAZW', 'HC',
#        'HNC', 'HRSP', 'HTOX', 'JOBS', 'LAND', 'METL', 'MINE', 'MSW', 'NREN',
#        'OZON', 'PEST', 'REN', 'SMOG', 'VADD', 'WATR', 'fips_str'],
#       dtype='object')

# %%
# Extract the 2-digit naics classification for each entry
df['relevant_naics'] = df['industry_code'].apply(lambda x: int(x[0:2]))

# extract and aggregate the relevant data
id_cols =        ['fips', 'relevant_naics']
bigness_cols =   ['emp', 'payann', 'estab']
indicator_cols = ['ACID', 'ENRG', 'ETOX', 'EUTR', 'FOOD', 'GCC', 'HAPS', 'HAZW', 'HC',
                  'HNC', 'HRSP', 'HTOX', 'JOBS', 'LAND', 'METL', 'MINE', 'MSW', 'NREN',
                  'OZON', 'PEST', 'REN', 'SMOG', 'VADD', 'WATR']

df2 = (df[id_cols + bigness_cols + indicator_cols]
       .groupby(by=['fips','relevant_naics'], as_index=False)
       .sum()
       .rename(columns={'fips':'id'})
      )

df2.head()
# Out:
#      id  relevant_naics  emp  payann  estab        ACID           ENRG  \
# 0  1001              11   30    1102      6    0.861581       0.275217
# 1  1001              21    0       0      2    0.000000       0.000000
# 2  1001              22  182   16657      9  284.165607  728617.651665
# 3  1001              31    0       0      5    0.000000       0.000000
# 4  1001              32    0       0      7    0.000000       0.000000
#
#          ETOX       EUTR      FOOD  ...      METL  MINE        MSW  \
# 0  893.717406   0.277371  0.818711  ...  0.000066   0.0   3.210888
# 1    0.000000   0.000000  0.000000  ...  0.000000   0.0   0.000000
# 2  204.647213  23.516440  6.054180  ...  0.047113   0.0  23.518978
# 3    0.000000   0.000000  0.000000  ...  0.000000   0.0   0.000000
# 4    0.000000   0.000000  0.000000  ...  0.000000   0.0   0.000000
#
#             NREN          OZON      PEST            REN         SMOG  \
# 0       0.000000  3.767853e-07  0.012181       0.275217    20.041190
# 1       0.000000  0.000000e+00  0.000000       0.000000     0.000000
# 2  435169.166702  1.886537e-03  0.000006  293448.484963  2400.143851
# 3       0.000000  0.000000e+00  0.000000       0.000000     0.000000
# 4       0.000000  0.000000e+00  0.000000       0.000000     0.000000
#
#            VADD         WATR
# 0    654.873075   136.234634
# 1      0.000000     0.000000
# 2  11995.153334  7473.552102
# 3      0.000000     0.000000
# 4      0.000000     0.000000
#
# [5 rows x 29 columns]

# %%
#
# Fill Missing Rows
#

def fill_missing_rows(df):

    n_rows = len(df.id.unique()) * len(df.relevant_naics.unique())
    product_iter = product(df.id.unique(), df.relevant_naics.unique())

    for id_val, naics_val in tqdm(product_iter, total=n_rows):
        check_exists = len(df.query(f'id=={id_val} & relevant_naics=={naics_val}'))

        if check_exists < 1:
            new_entry = pd.DataFrame(data={'id':id_val, 'relevant_naics': naics_val}, index=[0])
            yield new_entry

df_missing = pd.concat(fill_missing_rows(df2)).reset_index(drop=True)
df2 = (df2
       .append(df_missing)
       .fillna(0)
       .reset_index(drop=True)
      )
# Out:
# 100%|██████████| 65940/65940 [04:03<00:00, 270.91it/s]

# %%
df2
# Out:
#           id  relevant_naics  emp  payann  estab        ACID           ENRG  \
# 0       1001              11   30    1102      6    0.861581       0.275217
# 1       1001              21    0       0      2    0.000000       0.000000
# 2       1001              22  182   16657      9  284.165607  728617.651665
# 3       1001              31    0       0      5    0.000000       0.000000
# 4       1001              32    0       0      7    0.000000       0.000000
# ...      ...             ...  ...     ...    ...         ...            ...
# 60013  56045              61    0       0      1    0.000000       0.000000
# 60014  56045              62  101    2145     24    0.003288       0.043918
# 60015  56045              71    5     135      3    0.067368       0.107925
# 60016  56045              72   28    1438     23    0.006143       0.043024
# 60017  56045              81   39     762     21    0.002383       0.060362
#
#              ETOX       EUTR       FOOD  ...      METL  MINE        MSW  \
# 0      893.717406   0.277371   0.818711  ...  0.000066   0.0   3.210888
# 1        0.000000   0.000000   0.000000  ...  0.000000   0.0   0.000000
# 2      204.647213  23.516440   6.054180  ...  0.047113   0.0  23.518978
# 3        0.000000   0.000000   0.000000  ...  0.000000   0.0   0.000000
# 4        0.000000   0.000000   0.000000  ...  0.000000   0.0   0.000000
# ...           ...        ...        ...  ...       ...   ...        ...
# 60013    0.000000   0.000000   0.000000  ...  0.000000   0.0   0.000000
# 60014    0.005317   0.000638   7.678576  ...  0.000041   0.0  53.119870
# 60015   34.657328   0.040056   1.816929  ...  0.000011   0.0   5.620021
# 60016    0.260775   0.004386  27.025234  ...  0.000012   0.0  57.259023
# 60017    0.010647   0.001164   1.301033  ...  0.000006   0.0   6.369828
#
#                 NREN          OZON          PEST            REN         SMOG  \
# 0           0.000000  3.767853e-07  1.218061e-02       0.275217    20.041190
# 1           0.000000  0.000000e+00  0.000000e+00       0.000000     0.000000
# 2      435169.166702  1.886537e-03  5.996926e-06  293448.484963  2400.143851
# 3           0.000000  0.000000e+00  0.000000e+00       0.000000     0.000000
# 4           0.000000  0.000000e+00  0.000000e+00       0.000000     0.000000
# ...              ...           ...           ...            ...          ...
# 60013       0.000000  0.000000e+00  0.000000e+00       0.000000     0.000000
# 60014       0.000000  1.295951e-08  7.996942e-09       0.043918     0.130185
# 60015       0.000000  1.975391e-06  9.302177e-04       0.107925     2.744965
# 60016       0.000000  1.579423e-06  1.823160e-09       0.043024     0.686682
# 60017       0.000000  1.133122e-05  2.051391e-08       0.060362     1.638287
#
#                VADD         WATR
# 0        654.873075   136.234634
# 1          0.000000     0.000000
# 2      11995.153334  7473.552102
# 3          0.000000     0.000000
# 4          0.000000     0.000000
# ...             ...          ...
# 60013      0.000000     0.000000
# 60014   1450.711675     0.655140
# 60015     71.922583     6.531894
# 60016    756.297604     2.082064
# 60017    412.333305     0.502132
#
# [60018 rows x 29 columns]

# %%
naics_codes = pd.read_csv(base_dir.parent.parent / 'data_raw' / '2-digit_2012_NAICS_Codes.csv')
naics_codes.rename(columns={'2012 NAICS US   Code': 'code', 
                            '2012 NAICS US Title': 'details'},
                   inplace=True)

# naics_codes[naics_codes.code.apply(lambda x: True if len(x.split('-'))>1 else False)]
# naics_codes.set_index('2012 NAICS US   Code', inplace=True)
# naics_codes.columns

df2.relevant_naics = df2.relevant_naics.apply(lambda x: str(x).split('-')[0])
df2.head()
# Out:
#      id relevant_naics  emp  payann  estab        ACID           ENRG  \
# 0  1001             11   30    1102      6    0.861581       0.275217
# 1  1001             21    0       0      2    0.000000       0.000000
# 2  1001             22  182   16657      9  284.165607  728617.651665
# 3  1001             31    0       0      5    0.000000       0.000000
# 4  1001             32    0       0      7    0.000000       0.000000
#
#          ETOX       EUTR      FOOD  ...      METL  MINE        MSW  \
# 0  893.717406   0.277371  0.818711  ...  0.000066   0.0   3.210888
# 1    0.000000   0.000000  0.000000  ...  0.000000   0.0   0.000000
# 2  204.647213  23.516440  6.054180  ...  0.047113   0.0  23.518978
# 3    0.000000   0.000000  0.000000  ...  0.000000   0.0   0.000000
# 4    0.000000   0.000000  0.000000  ...  0.000000   0.0   0.000000
#
#             NREN          OZON      PEST            REN         SMOG  \
# 0       0.000000  3.767853e-07  0.012181       0.275217    20.041190
# 1       0.000000  0.000000e+00  0.000000       0.000000     0.000000
# 2  435169.166702  1.886537e-03  0.000006  293448.484963  2400.143851
# 3       0.000000  0.000000e+00  0.000000       0.000000     0.000000
# 4       0.000000  0.000000e+00  0.000000       0.000000     0.000000
#
#            VADD         WATR
# 0    654.873075   136.234634
# 1      0.000000     0.000000
# 2  11995.153334  7473.552102
# 3      0.000000     0.000000
# 4      0.000000     0.000000
#
# [5 rows x 29 columns]

# %%
def flatten_multi_naics(naic_code):
    naic_code = int(naic_code)
    if naic_code in (31, 32, 33):
        return 31
    elif naic_code in (44, 45):
        return 44
    elif naic_code in (48, 49):
        return 48
    else:
        return naic_code



df2.relevant_naics = df2.relevant_naics.swifter.apply(flatten_multi_naics)

df2.relevant_naics.unique()
# Out:
# /Users/merrelbook/anaconda3/envs/datalab/lib/python3.7/site-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# Pandas Apply: 100%|██████████| 60018/60018 [00:00<00:00, 460313.96it/s]
# array([11, 21, 22, 31, 44, 48, 51, 52, 53, 54, 55, 56, 61, 62, 71, 72, 81])

# %%
def expand_range(x):
    if '-' in x:
        n = x.split('-')
        return str([l for l in range(int(n[0]), int(n[1])+1)]).strip('[]')
    else:
        return x


    
naics_2 = naics_codes[naics_codes.code.apply(lambda x: True if (len(x)==2) or ('-' in x) else False)]
naics_2.code = naics_2.code.apply(expand_range)

def lookup_naics_details(row):
    n = row.relevant_naics
#     print(str(int(n)))
    try:
        d = naics_2[naics_2.code.str.contains(str(int(n)))]['details'].values[0]
    except IndexError:
        print(n)
        d = n
    
    return d
# Out:
# /Users/merrelbook/anaconda3/envs/datalab/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
naics_2
# Out:
#             code                                            details
# 0             11         Agriculture, Forestry, Fishing and Hunting
# 131           21      Mining, Quarrying, and Oil and Gas Extraction
# 179           22                                          Utilities
# 204           23                                       Construction
# 277   31, 32, 33                                      Manufacturing
# 929           42                                    Wholesale Trade
# 1094      44, 45                                       Retail Trade
# 1261      48, 49                     Transportation and Warehousing
# 1401          51                                        Information
# 1479          52                              Finance and Insurance
# 1568          53                 Real Estate and Rental and Leasing
# 1623          54   Professional, Scientific, and Technical Services
# 1717          55            Management of Companies and Enterprises
# 1724          56  Administrative and Support and Waste Managemen...
# 1811          61                               Educational Services
# 1849          62                  Health Care and Social Assistance
# 1941          71                Arts, Entertainment, and Recreation
# 2002          72                    Accommodation and Food Services
# 2036          81      Other Services (except Public Administration)
# 2134          92                              Public Administration

# %%
lookup_naics_details(df2.loc[3,:])
# Out:
# 'Manufacturing'

# %%
df2['industry_detail'] = df2.swifter.apply(lookup_naics_details, axis=1)

df2['id'] = df2['id'].swifter.apply(fips_to_str)

df2.head()
# Out:
# Dask Apply: 100%|██████████| 16/16 [00:09<00:00,  1.62it/s]
# /Users/merrelbook/anaconda3/envs/datalab/lib/python3.7/site-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# Pandas Apply: 100%|██████████| 60018/60018 [00:00<00:00, 358581.79it/s]
#       id  relevant_naics  emp  payann  estab        ACID           ENRG  \
# 0  01001              11   30    1102      6    0.861581       0.275217
# 1  01001              21    0       0      2    0.000000       0.000000
# 2  01001              22  182   16657      9  284.165607  728617.651665
# 3  01001              31    0       0      5    0.000000       0.000000
# 4  01001              31    0       0      7    0.000000       0.000000
#
#          ETOX       EUTR      FOOD  ...  MINE        MSW           NREN  \
# 0  893.717406   0.277371  0.818711  ...   0.0   3.210888       0.000000
# 1    0.000000   0.000000  0.000000  ...   0.0   0.000000       0.000000
# 2  204.647213  23.516440  6.054180  ...   0.0  23.518978  435169.166702
# 3    0.000000   0.000000  0.000000  ...   0.0   0.000000       0.000000
# 4    0.000000   0.000000  0.000000  ...   0.0   0.000000       0.000000
#
#            OZON      PEST            REN         SMOG          VADD  \
# 0  3.767853e-07  0.012181       0.275217    20.041190    654.873075
# 1  0.000000e+00  0.000000       0.000000     0.000000      0.000000
# 2  1.886537e-03  0.000006  293448.484963  2400.143851  11995.153334
# 3  0.000000e+00  0.000000       0.000000     0.000000      0.000000
# 4  0.000000e+00  0.000000       0.000000     0.000000      0.000000
#
#           WATR                                industry_detail
# 0   136.234634     Agriculture, Forestry, Fishing and Hunting
# 1     0.000000  Mining, Quarrying, and Oil and Gas Extraction
# 2  7473.552102                                      Utilities
# 3     0.000000                                  Manufacturing
# 4     0.000000                                  Manufacturing
#
# [5 rows x 30 columns]

# %%
df2.to_csv(
    data_dir / 'tables_for_viz' / 'final_industry_byCounty_byType.tsv',
    index=False, sep='\t'
)

# %%
df_key = (df2[['relevant_naics', 'industry_detail']]
          .groupby('industry_detail').first()
          .sort_values(by='relevant_naics'))

df_key.to_csv(
    data_dir / 'tables_for_viz' / 'industry_ID_list.csv',
#     index=False
)

df_key.head()
# Out:
#                                                relevant_naics
# industry_detail
# Agriculture, Forestry, Fishing and Hunting                 11
# Mining, Quarrying, and Oil and Gas Extraction              21
# Utilities                                                  22
# Manufacturing                                              31
# Retail Trade                                               44

# %%
df2
# Out:
#           id  relevant_naics    emp   payann  estab  \
# 0      01001              11   30.0   1102.0    6.0
# 1      01001              21    0.0      0.0    2.0
# 2      01001              22  182.0  16657.0    9.0
# 3      01001              31    0.0      0.0    5.0
# 4      01001              31    0.0      0.0    7.0
# ...      ...             ...    ...      ...    ...
# 65935  56043              55    0.0      0.0    0.0
# 65936  56043              48    0.0      0.0    0.0
# 65937  56045              31    0.0      0.0    0.0
# 65938  56045              31    0.0      0.0    0.0
# 65939  56045              48    0.0      0.0    0.0
#
#                                      industry_detail
# 0         Agriculture, Forestry, Fishing and Hunting
# 1      Mining, Quarrying, and Oil and Gas Extraction
# 2                                          Utilities
# 3                                      Manufacturing
# 4                                      Manufacturing
# ...                                              ...
# 65935        Management of Companies and Enterprises
# 65936                 Transportation and Warehousing
# 65937                                  Manufacturing
# 65938                                  Manufacturing
# 65939                 Transportation and Warehousing
#
# [65940 rows x 6 columns]

# %%
len(df.industry_code.unique())
