# %%
import pathlib
import pandas as pd
import numpy as np

# %% [markdown]
# ### Goal: Process Cancer Incidence Data --> .tsv for choropleth
#
# Current US choropleth example takes .tsv with the following format:
#
# ```
# id	rate
# 01001	5.1
# 01003	4.9
# 01005	8.6
# 01007	6.2
# ```
#
# where id is the county FIPS and rate is some value for coloring the choropleth

# %%
# Functions
def fips_to_str(fips):
    fips_str = str(int(fips))

    while len(fips_str) < 5:
        fips_str = '0' + fips_str

    return fips_str


def extract_state_fips(fips_str):
    return int(fips_str[0:2])


def compute_delta(row):
    national_rate = df_us_cancer_rates.loc[row.cancer, 'rate']
    return row.rate - national_rate


def compute_delta_percent(row):
    national_rate = df_us_cancer_rates.loc[row.cancer, 'rate']
    percent = 100 * ((row.rate - national_rate)/national_rate)
    return percent

# %%
base_dir = pathlib.Path.cwd()

# Load list of all county fips
county_fips_file = base_dir.parent.parent / 'data_raw' / 'counties_fips.csv'
counties = pd.read_csv(county_fips_file)
counties['fips_str'] = counties.FIPS.apply(fips_to_str)

# Load the cancer incidence data
data_dir = base_dir.parent.parent / 'data_clean' / 'CDC_CancerByCounty' / 'incidencerates'

incidence_data_csv = data_dir / 'cancer_by_type.csv'

# Load ALL incidence rate data to dataframe
df = pd.read_csv(incidence_data_csv)

# Some initial additions
df['fips_str'] = df.fips.apply(fips_to_str)
df['fips_state'] = df.fips_str.apply(extract_state_fips)
df['rate'] = df['incidence rate_per_100000']

#
# Some initial cleaning
#

# # Exclude Kansas and Minnesota due to missing data
# df = df[~df.state.isin(['kansas', 'minnesota'])]

# # Handle cases where rate value includes trailing ' #'
# df['rate'] = df['rate'].apply(
#     lambda x: float(x.strip(' #')) if '#' in x else x
# )

# # Handle all remaining non-numeric entries
# df.rate = (pd
#              .to_numeric(df.rate, errors='coerce')
#              .replace(np.nan, 0, regex=True)
#           )

# %%
df[(df.state=='newmexico') & (df.cancer==1)]
# Out:
#                        locale     fips met_health_obj  \
# 32876         New Mexico(7,8)  35000.0            ***
# 32899  Bernalillo County(7,8)  35001.0            ***
# 32922      Catron County(7,8)  35003.0            ***
# 32945      Chaves County(7,8)  35005.0            ***
# 32968      Cibola County(7,8)  35006.0            ***
# 32991      Colfax County(7,8)  35007.0            ***
# 33014       Curry County(7,8)  35009.0            ***
# 33037     De Baca County(7,8)  35011.0            ***
# 33060    Dona Ana County(7,8)  35013.0            ***
# 33083        Eddy County(7,8)  35015.0            ***
# 33110   Guadalupe County(7,8)  35019.0            ***
# 33133     Harding County(7,8)  35021.0            ***
# 33156     Hidalgo County(7,8)  35023.0            ***
# 33179         Lea County(7,8)  35025.0            ***
# 33202  Los Alamos County(7,8)  35028.0            ***
# 33225        Luna County(7,8)  35029.0            ***
# 33248    McKinley County(7,8)  35031.0            ***
# 33271        Mora County(7,8)  35033.0            ***
# 33294       Otero County(7,8)  35035.0            ***
# 33317        Quay County(7,8)  35037.0            ***
# 33340  Rio Arriba County(7,8)  35039.0            ***
# 33363   Roosevelt County(7,8)  35041.0            ***
# 33386    Sandoval County(7,8)  35043.0            ***
# 33409    San Juan County(7,8)  35045.0            ***
# 33432  San Miguel County(7,8)  35047.0            ***
# 33455    Santa Fe County(7,8)  35049.0            ***
# 33483     Socorro County(7,8)  35053.0            ***
# 33506        Taos County(7,8)  35055.0            ***
# 33529    Torrance County(7,8)  35057.0            ***
# 33556    Valencia County(7,8)  35061.0            ***
#
#       incidence rate_per_100000 incidence rate_lower_95_confidence  \
# 32876                     374.3                              370.8
# 32899                     390.0                              383.6
# 32922                     254.0                              203.5
# 32945                     367.2                              347.5
# 32968                     338.7                              309.7
# 32991                     366.6                              326.8
# 33014                     370.8                              346.3
# 33037                     419.3                              310.2
# 33060                     390.7                              379.0
# 33083                     375.8                              354.2
# 33110                     377.9                              309.6
# 33133                     481.5                              274.7
# 33156                     360.0                              294.0
# 33179                     364.5                              343.4
# 33202                     423.8                              385.8
# 33225                     401.1                              370.1
# 33248                     302.0                              283.3
# 33271                     354.5                              287.9
# 33294                     417.0                              396.3
# 33317                     449.5                              397.3
# 33340                     324.7                              302.0
# 33363                     349.1                              312.3
# 33386                     409.8                              395.5
# 33409                     340.6                              326.4
# 33432                     349.7                              322.7
# 33455                     322.0                              310.6
# 33483                     383.6                              346.1
# 33506                     323.1                              299.6
# 33529                     444.2                              402.3
# 33556                     392.5                              373.9
#
#       incidence rate_upper_95_confidence annual_count_avg recent_trend_str  \
# 32876                              377.9           9116.0          falling
# 32899                              396.5           2957.0          falling
# 32922                              321.4             21.0          falling
# 32945                              387.7            272.0          falling
# 32968                              369.8            104.0           stable
# 32991                              410.6             73.0           stable
# 33014                              396.5            176.0          falling
# 33037                              558.8             12.0           stable
# 33060                              402.6            883.0           stable
# 33083                              398.3            238.0          falling
# 33110                              458.1             22.0           stable
# 33133                              797.1              6.0           stable
# 33156                              437.7             23.0           stable
# 33179                              386.5            229.0          falling
# 33202                              464.8             99.0          falling
# 33225                              434.3            135.0           stable
# 33248                              321.6            202.0          falling
# 33271                              433.1             24.0           stable
# 33294                              438.5            320.0           stable
# 33317                              507.5             62.0           rising
# 33340                              348.8            162.0           stable
# 33363                              389.1             67.0          falling
# 33386                              424.5            668.0          falling
# 33409                              355.3            451.0          falling
# 33432                              378.4            136.0           stable
# 33455                              333.7            678.0          falling
# 33483                              424.2             82.0           stable
# 33506                              348.2            161.0          falling
# 33529                              489.6             93.0           stable
# 33556                              411.9            354.0          falling
#
#       trend_last_5 trend_last_5_lower_95_confidence  ... sex  \
# 32876         -1.7                             -2.2  ...   0
# 32899         -0.8                             -0.9  ...   0
# 32922         -8.4                            -12.7  ...   0
# 32945         -3.0                             -4.8  ...   0
# 32968         -0.4                             -1.0  ...   0
# 32991         -1.8                             -4.6  ...   0
# 33014         -0.6                             -1.1  ...   0
# 33037          0.2                             -1.4  ...   0
# 33060          0.4                             -0.4  ...   0
# 33083         -0.9                             -1.4  ...   0
# 33110         -0.6                             -1.7  ...   0
# 33133        -25.6                            -61.8  ...   0
# 33156          0.8                             -0.4  ...   0
# 33179         -0.8                             -1.4  ...   0
# 33202         -1.0                             -1.5  ...   0
# 33225          0.2                             -0.4  ...   0
# 33248         -4.0                             -7.7  ...   0
# 33271         -0.1                             -1.3  ...   0
# 33294          0.1                             -0.3  ...   0
# 33317          0.9                              0.1  ...   0
# 33340         -0.6                             -1.2  ...   0
# 33363         -2.7                             -4.9  ...   0
# 33386         -0.6                             -1.0  ...   0
# 33409         -0.6                             -1.0  ...   0
# 33432         -0.3                             -0.8  ...   0
# 33455         -4.1                             -5.3  ...   0
# 33483          0.2                             -0.3  ...   0
# 33506         -0.8                             -1.4  ...   0
# 33529          0.3                             -0.4  ...   0
# 33556         -0.7                             -1.1  ...   0
#
#                                               source_url stage  stateFIPS  \
# 32876  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 32899  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 32922  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 32945  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 32968  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 32991  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33014  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33037  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33060  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33083  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33110  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33133  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33156  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33179  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33202  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33225  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33248  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33271  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33294  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33317  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33340  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33363  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33386  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33409  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33432  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33455  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33483  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33506  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33529  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
# 33556  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35
#
#        type      state  cancer_description fips_str  fips_state   rate
# 32876  incd  newmexico    All Cancer Sites    35000          35  374.3
# 32899  incd  newmexico    All Cancer Sites    35001          35  390.0
# 32922  incd  newmexico    All Cancer Sites    35003          35  254.0
# 32945  incd  newmexico    All Cancer Sites    35005          35  367.2
# 32968  incd  newmexico    All Cancer Sites    35006          35  338.7
# 32991  incd  newmexico    All Cancer Sites    35007          35  366.6
# 33014  incd  newmexico    All Cancer Sites    35009          35  370.8
# 33037  incd  newmexico    All Cancer Sites    35011          35  419.3
# 33060  incd  newmexico    All Cancer Sites    35013          35  390.7
# 33083  incd  newmexico    All Cancer Sites    35015          35  375.8
# 33110  incd  newmexico    All Cancer Sites    35019          35  377.9
# 33133  incd  newmexico    All Cancer Sites    35021          35  481.5
# 33156  incd  newmexico    All Cancer Sites    35023          35  360.0
# 33179  incd  newmexico    All Cancer Sites    35025          35  364.5
# 33202  incd  newmexico    All Cancer Sites    35028          35  423.8
# 33225  incd  newmexico    All Cancer Sites    35029          35  401.1
# 33248  incd  newmexico    All Cancer Sites    35031          35  302.0
# 33271  incd  newmexico    All Cancer Sites    35033          35  354.5
# 33294  incd  newmexico    All Cancer Sites    35035          35  417.0
# 33317  incd  newmexico    All Cancer Sites    35037          35  449.5
# 33340  incd  newmexico    All Cancer Sites    35039          35  324.7
# 33363  incd  newmexico    All Cancer Sites    35041          35  349.1
# 33386  incd  newmexico    All Cancer Sites    35043          35  409.8
# 33409  incd  newmexico    All Cancer Sites    35045          35  340.6
# 33432  incd  newmexico    All Cancer Sites    35047          35  349.7
# 33455  incd  newmexico    All Cancer Sites    35049          35  322.0
# 33483  incd  newmexico    All Cancer Sites    35053          35  383.6
# 33506  incd  newmexico    All Cancer Sites    35055          35  323.1
# 33529  incd  newmexico    All Cancer Sites    35057          35  444.2
# 33556  incd  newmexico    All Cancer Sites    35061          35  392.5
#
# [30 rows x 26 columns]

# %% [markdown]
# ### Process the National Level Cancer Data

# %%
df.query('fips==0')

columns = ['fips', 'fips_str', 'rate', 'cancer']

df_us_cancer_rates = df.query('fips==0')[columns]
df_us_cancer_rates.fips = df_us_cancer_rates.fips.apply(int)

# df_us_cancer_rates.rate = (pd
#                          .to_numeric(df_us_cancer_rates.rate, errors='coerce')
#                          .replace(np.nan, 0, regex=True)
#                         )

# rename columns
df_us_cancer_rates.rename(columns={'fips_str': 'id'}, inplace=True)
df_us_cancer_rates.drop(['fips', 'id'], inplace=True, axis=1)
df_us_cancer_rates.set_index('cancer', inplace=True)

# Save cancer data to tsv
tsv_out_path = data_dir.parent / f'cancer_US_byType.tsv'
# df_us_cancer_rates.to_csv(tsv_out_path, sep='\t', index=False)

df_us_cancer_rates.head()
# Out:
#          rate
# cancer
# 1       448.0
# 3        11.7
# 17        4.5
# 18        6.6
# 20       38.7

# %% [markdown]
# ### Process the county Level Data

# %%
# cancer_id

criterion = ((df.stage.isna()))

columns = ['fips', 'fips_str', 'rate', 'cancer', 'state']

df_cancer_type = df[criterion][columns]

# Sort values by fips
df_cancer_type.sort_values(by=['cancer','fips'], inplace=True)

# Some initial cleaning
# df_cancer_type.rename(columns={'incidence rate_per_100000': 'rate'}, inplace=True)
df_cancer_type.fips = df_cancer_type.fips.apply(int)

df_county_cancer_rates = df_cancer_type[df_cancer_type.fips.isin(counties.fips_str.tolist())]

# df_county_cancer_rates.rate = (pd
#                          .to_numeric(df_county_cancer_rates.rate, errors='coerce')
#                          .replace(np.nan, 0, regex=True)
#                         )

# rename columns
df_county_cancer_rates.rename(columns={'fips_str': 'id'}, inplace=True)
df_county_cancer_rates.drop('fips', inplace=True, axis=1)


# Process the delta form national average
df_county_cancer_rates['rate_delta'] = df_county_cancer_rates.apply(compute_delta, axis=1)
df_county_cancer_rates['rate_delta_percent'] = df_county_cancer_rates.apply(compute_delta_percent, axis=1)

# Save cancer data to tsv
tsv_out_path = data_dir.parent / f'cancer_byCounty_byType.tsv'
df_county_cancer_rates.to_csv(tsv_out_path, sep='\t', index=False)

df_county_cancer_rates.head()
# Out:
# /Users/merrelbook/anaconda3/envs/datalab/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /Users/merrelbook/anaconda3/envs/datalab/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /Users/merrelbook/anaconda3/envs/datalab/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/merrelbook/anaconda3/envs/datalab/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         id   rate  cancer    state  rate_delta  rate_delta_percent
# 46   01001  495.6       1  alabama        47.6           10.625000
# 69   01003  445.0       1  alabama        -3.0           -0.669643
# 92   01005  429.8       1  alabama       -18.2           -4.062500
# 115  01007  478.3       1  alabama        30.3            6.763393
# 138  01009  440.0       1  alabama        -8.0           -1.785714
