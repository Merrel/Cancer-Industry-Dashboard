# %%
import pathlib
import pandas as pd
import numpy as np

# %% [markdown]
# ### Goal: Process Cancer Incidence Data --> .tsv for choropleth
#
# Current US choropleth example takes .tsv with the following format:
#
# ```
# id	rate
# 01001	5.1
# 01003	4.9
# 01005	8.6
# 01007	6.2
# ```
#
# where id is the county FIPS and rate is some value for coloring the choropleth

# %%
# Functions
def fips_to_str(fips):
    fips_str = str(int(fips))

    while len(fips_str) < 5:
        fips_str = '0' + fips_str

    return fips_str


def extract_state_fips(fips_str):
    return int(fips_str[0:2])


def compute_delta(row):
    national_rate = df_us_cancer_rates.loc[row.cancer, 'rate']
    return row.rate - national_rate


def compute_delta_percent(row):
    national_rate = df_us_cancer_rates.loc[row.cancer, 'rate']
    percent = 100 * ((row.rate - national_rate)/national_rate)
    return percent

# %%
base_dir = pathlib.Path.cwd()

# Load list of all county fips
county_fips_file = base_dir.parent.parent / 'data_raw' / 'counties_fips.csv'
counties = pd.read_csv(county_fips_file)
counties['fips_str'] = counties.FIPS.apply(fips_to_str)

# Load the cancer incidence data
data_dir = base_dir.parent.parent / 'data_clean' / 'CDC_CancerByCounty' / 'incidencerates'

incidence_data_csv = data_dir / 'cancer_by_type.csv'

# Load ALL incidence rate data to dataframe
df = pd.read_csv(incidence_data_csv)

# Some initial additions
df['fips_str'] = df.fips.apply(fips_to_str)
df['fips_state'] = df.fips_str.apply(extract_state_fips)
df['rate'] = df['incidence rate_per_100000']

#
# Some initial cleaning
#

# Exclude Kansas and Minnesota due to missing data
df = df[~df.state.isin(['kansas', 'minnesota'])]

# Handle cases where rate value includes trailing ' #'
df['rate'] = df['rate'].apply(
    lambda x: float(x.strip(' #')) if '#' in x else x
)

# Handle all remaining non-numeric entries
df.rate = (pd
             .to_numeric(df.rate, errors='coerce')
             .replace(np.nan, 0, regex=True)
          )

# %%
df.columns
# Out:
# Index(['locale', 'fips', 'met_health_obj', 'incidence rate_per_100000',
#        'incidence rate_lower_95_confidence',
#        'incidence rate_upper_95_confidence', 'annual_count_avg',
#        'recent_trend_str', 'trend_last_5', 'trend_last_5_lower_95_confidence',
#        'trend_last_5_upper_95_confidence', 'age', 'areatype', 'cancer',
#        'file_name', 'race', 'sex', 'source_url', 'stage', 'stateFIPS', 'type',
#        'state', 'cancer_description', 'fips_str', 'fips_state', 'rate'],
#       dtype='object')

# %%
df[(df.state=='newmexico') & (df.cancer==1)].reset_index(drop=True)
# Out:
#                     locale     fips met_health_obj incidence rate_per_100000  \
# 0     US (SEER+NPCR)(1,10)      0.0            ***                     448.0
# 1          New Mexico(7,8)  35000.0            ***                     374.3
# 2   Bernalillo County(7,8)  35001.0            ***                     390.0
# 3       Catron County(7,8)  35003.0            ***                     254.0
# 4       Chaves County(7,8)  35005.0            ***                     367.2
# 5       Cibola County(7,8)  35006.0            ***                     338.7
# 6       Colfax County(7,8)  35007.0            ***                     366.6
# 7        Curry County(7,8)  35009.0            ***                     370.8
# 8      De Baca County(7,8)  35011.0            ***                     419.3
# 9     Dona Ana County(7,8)  35013.0            ***                     390.7
# 10        Eddy County(7,8)  35015.0            ***                     375.8
# 11       Grant County(7,8)  35017.0            ***                     339.9
# 12   Guadalupe County(7,8)  35019.0            ***                     377.9
# 13     Harding County(7,8)  35021.0            ***                     481.5
# 14     Hidalgo County(7,8)  35023.0            ***                     360.0
# 15         Lea County(7,8)  35025.0            ***                     364.5
# 16     Lincoln County(7,8)  35027.0            ***                     360.6
# 17  Los Alamos County(7,8)  35028.0            ***                     423.8
# 18        Luna County(7,8)  35029.0            ***                     401.1
# 19    McKinley County(7,8)  35031.0            ***                     302.0
# 20        Mora County(7,8)  35033.0            ***                     354.5
# 21       Otero County(7,8)  35035.0            ***                     417.0
# 22        Quay County(7,8)  35037.0            ***                     449.5
# 23  Rio Arriba County(7,8)  35039.0            ***                     324.7
# 24   Roosevelt County(7,8)  35041.0            ***                     349.1
# 25    Sandoval County(7,8)  35043.0            ***                     409.8
# 26    San Juan County(7,8)  35045.0            ***                     340.6
# 27  San Miguel County(7,8)  35047.0            ***                     349.7
# 28    Santa Fe County(7,8)  35049.0            ***                     322.0
# 29      Sierra County(7,8)  35051.0            ***                     393.7
# 30     Socorro County(7,8)  35053.0            ***                     383.6
# 31        Taos County(7,8)  35055.0            ***                     323.1
# 32    Torrance County(7,8)  35057.0            ***                     444.2
# 33       Union County(7,8)  35059.0            ***                     280.6
# 34    Valencia County(7,8)  35061.0            ***                     392.5
#
#    incidence rate_lower_95_confidence incidence rate_upper_95_confidence  \
# 0                               447.7                              448.4
# 1                               370.8                              377.9
# 2                               383.6                              396.5
# 3                               203.5                              321.4
# 4                               347.5                              387.7
# 5                               309.7                              369.8
# 6                               326.8                              410.6
# 7                               346.3                              396.5
# 8                               310.2                              558.8
# 9                               379.0                              402.6
# 10                              354.2                              398.3
# 11                              314.3                              367.4
# 12                              309.6                              458.1
# 13                              274.7                              797.1
# 14                              294.0                              437.7
# 15                              343.4                              386.5
# 16                              328.8                              395.1
# 17                              385.8                              464.8
# 18                              370.1                              434.3
# 19                              283.3                              321.6
# 20                              287.9                              433.1
# 21                              396.3                              438.5
# 22                              397.3                              507.5
# 23                              302.0                              348.8
# 24                              312.3                              389.1
# 25                              395.5                              424.5
# 26                              326.4                              355.3
# 27                              322.7                              378.4
# 28                              310.6                              333.7
# 29                              355.6                              436.2
# 30                              346.1                              424.2
# 31                              299.6                              348.2
# 32                              402.3                              489.6
# 33                              223.0                              350.2
# 34                              373.9                              411.9
#
#    annual_count_avg recent_trend_str trend_last_5  \
# 0         1638110.0          falling         -0.9
# 1            9116.0          falling         -1.7
# 2            2957.0          falling         -0.8
# 3              21.0          falling         -8.4
# 4             272.0          falling         -3.0
# 5             104.0           stable         -0.4
# 6              73.0           stable         -1.8
# 7             176.0          falling         -0.6
# 8              12.0           stable          0.2
# 9             883.0           stable          0.4
# 10            238.0          falling         -0.9
# 11            155.0          falling         -1.5
# 12             22.0           stable         -0.6
# 13              6.0           stable        -25.6
# 14             23.0           stable          0.8
# 15            229.0          falling         -0.8
# 16            119.0          falling         -1.8
# 17             99.0          falling         -1.0
# 18            135.0           stable          0.2
# 19            202.0          falling         -4.0
# 20             24.0           stable         -0.1
# 21            320.0           stable          0.1
# 22             62.0           rising          0.9
# 23            162.0           stable         -0.6
# 24             67.0          falling         -2.7
# 25            668.0          falling         -0.6
# 26            451.0          falling         -0.6
# 27            136.0           stable         -0.3
# 28            678.0          falling         -4.1
# 29             98.0           stable         -0.4
# 30             82.0           stable          0.2
# 31            161.0          falling         -0.8
# 32             93.0           stable          0.3
# 33             17.0           stable          6.3
# 34            354.0          falling         -0.7
#
#    trend_last_5_lower_95_confidence  ... sex  \
# 0                              -1.6  ...   0
# 1                              -2.2  ...   0
# 2                              -0.9  ...   0
# 3                             -12.7  ...   0
# 4                              -4.8  ...   0
# 5                              -1.0  ...   0
# 6                              -4.6  ...   0
# 7                              -1.1  ...   0
# 8                              -1.4  ...   0
# 9                              -0.4  ...   0
# 10                             -1.4  ...   0
# 11                             -2.2  ...   0
# 12                             -1.7  ...   0
# 13                            -61.8  ...   0
# 14                             -0.4  ...   0
# 15                             -1.4  ...   0
# 16                             -2.3  ...   0
# 17                             -1.5  ...   0
# 18                             -0.4  ...   0
# 19                             -7.7  ...   0
# 20                             -1.3  ...   0
# 21                             -0.3  ...   0
# 22                              0.1  ...   0
# 23                             -1.2  ...   0
# 24                             -4.9  ...   0
# 25                             -1.0  ...   0
# 26                             -1.0  ...   0
# 27                             -0.8  ...   0
# 28                             -5.3  ...   0
# 29                             -1.1  ...   0
# 30                             -0.3  ...   0
# 31                             -1.4  ...   0
# 32                             -0.4  ...   0
# 33                             -8.6  ...   0
# 34                             -1.1  ...   0
#
#                                            source_url stage  stateFIPS  type  \
# 0   https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 1   https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 2   https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 3   https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 4   https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 5   https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 6   https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 7   https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 8   https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 9   https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 10  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 11  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 12  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 13  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 14  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 15  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 16  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 17  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 18  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 19  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 20  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 21  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 22  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 23  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 24  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 25  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 26  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 27  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 28  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 29  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 30  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 31  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 32  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 33  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
# 34  https://www.statecancerprofiles.cancer.gov/inc...   NaN         35  incd
#
#         state  cancer_description fips_str  fips_state   rate
# 0   newmexico    All Cancer Sites    00000           0  448.0
# 1   newmexico    All Cancer Sites    35000          35  374.3
# 2   newmexico    All Cancer Sites    35001          35  390.0
# 3   newmexico    All Cancer Sites    35003          35  254.0
# 4   newmexico    All Cancer Sites    35005          35  367.2
# 5   newmexico    All Cancer Sites    35006          35  338.7
# 6   newmexico    All Cancer Sites    35007          35  366.6
# 7   newmexico    All Cancer Sites    35009          35  370.8
# 8   newmexico    All Cancer Sites    35011          35  419.3
# 9   newmexico    All Cancer Sites    35013          35  390.7
# 10  newmexico    All Cancer Sites    35015          35  375.8
# 11  newmexico    All Cancer Sites    35017          35  339.9
# 12  newmexico    All Cancer Sites    35019          35  377.9
# 13  newmexico    All Cancer Sites    35021          35  481.5
# 14  newmexico    All Cancer Sites    35023          35  360.0
# 15  newmexico    All Cancer Sites    35025          35  364.5
# 16  newmexico    All Cancer Sites    35027          35  360.6
# 17  newmexico    All Cancer Sites    35028          35  423.8
# 18  newmexico    All Cancer Sites    35029          35  401.1
# 19  newmexico    All Cancer Sites    35031          35  302.0
# 20  newmexico    All Cancer Sites    35033          35  354.5
# 21  newmexico    All Cancer Sites    35035          35  417.0
# 22  newmexico    All Cancer Sites    35037          35  449.5
# 23  newmexico    All Cancer Sites    35039          35  324.7
# 24  newmexico    All Cancer Sites    35041          35  349.1
# 25  newmexico    All Cancer Sites    35043          35  409.8
# 26  newmexico    All Cancer Sites    35045          35  340.6
# 27  newmexico    All Cancer Sites    35047          35  349.7
# 28  newmexico    All Cancer Sites    35049          35  322.0
# 29  newmexico    All Cancer Sites    35051          35  393.7
# 30  newmexico    All Cancer Sites    35053          35  383.6
# 31  newmexico    All Cancer Sites    35055          35  323.1
# 32  newmexico    All Cancer Sites    35057          35  444.2
# 33  newmexico    All Cancer Sites    35059          35  280.6
# 34  newmexico    All Cancer Sites    35061          35  392.5
#
# [35 rows x 26 columns]

# %% [markdown]
# ### Process the National Level Cancer Data

# %%
df.query('fips==0')

columns = ['fips', 'fips_str', 'rate', 'cancer']

df_us_cancer_rates = df.query('fips==0')[columns]
df_us_cancer_rates.fips = df_us_cancer_rates.fips.apply(int)

# rename columns
df_us_cancer_rates.rename(columns={'fips_str': 'id'}, inplace=True)
df_us_cancer_rates.drop(['fips', 'id'], inplace=True, axis=1)
df_us_cancer_rates.set_index('cancer', inplace=True)
df_us_cancer_rates.drop_duplicates(inplace=True)

# Save cancer data to tsv
tsv_out_path = data_dir.parent / f'cancer_US_byType.tsv'
# df_us_cancer_rates.to_csv(tsv_out_path, sep='\t', index=False)

df_us_cancer_rates.head()
# Out:
#          rate
# cancer
# 1       448.0
# 3        11.7
# 17        4.5
# 18        6.6
# 20       38.7

# %% [markdown]
# ### Process the county Level Data

# %%
# cancer_id

criterion = ((df.stage.isna()))

columns = ['fips', 'fips_str', 'rate', 'cancer', 'state']

df_cancer_type = df[criterion][columns]

# Sort values by fips
df_cancer_type.sort_values(by=['cancer','fips'], inplace=True)

# Some initial cleaning
# df_cancer_type.rename(columns={'incidence rate_per_100000': 'rate'}, inplace=True)
df_cancer_type.fips = df_cancer_type.fips.apply(int)

df_county_cancer_rates = df_cancer_type[df_cancer_type.fips.isin(counties.fips_str.tolist())]

# df_county_cancer_rates.rate = (pd
#                          .to_numeric(df_county_cancer_rates.rate, errors='coerce')
#                          .replace(np.nan, 0, regex=True)
#                         )

# rename columns
df_county_cancer_rates.rename(columns={'fips_str': 'id'}, inplace=True)
df_county_cancer_rates.drop('fips', inplace=True, axis=1)


# Process the delta form national average
df_county_cancer_rates['rate_delta'] = df_county_cancer_rates.apply(compute_delta, axis=1)
df_county_cancer_rates['rate_delta_percent'] = df_county_cancer_rates.apply(compute_delta_percent, axis=1)

# Save cancer data to tsv
tsv_out_path = data_dir.parent / f'cancer_byCounty_byType.tsv'
df_county_cancer_rates.to_csv(tsv_out_path, sep='\t', index=False)

df_county_cancer_rates.head()
# Out:
# /Users/merrelbook/anaconda3/envs/datalab/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /Users/merrelbook/anaconda3/envs/datalab/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /Users/merrelbook/anaconda3/envs/datalab/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/merrelbook/anaconda3/envs/datalab/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          id   rate  cancer    state  rate_delta  rate_delta_percent
# 1173  01001  495.6       1  alabama        47.6           10.625000
# 1196  01003  445.0       1  alabama        -3.0           -0.669643
# 1219  01005  429.8       1  alabama       -18.2           -4.062500
# 1242  01007  478.3       1  alabama        30.3            6.763393
# 1265  01009  440.0       1  alabama        -8.0           -1.785714
