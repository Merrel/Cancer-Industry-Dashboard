# %%
import fiona
import pandas as pd
import geopandas as gpd
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from pathlib import Path

# %%
#
# Explore the shapefiles
#

# Load the data
project_dir = Path('/Users/merrelbook/Projects/HealthDataVizGA')
data_dir = project_dir / 'DataVisualAnalytics_Industries-cancer' / 'data_raw'
data_path = data_dir / 'US_Shape_Files' / 'cb_2018_us_county_500k.zip'

# Read direct from the .zip file -- See: https://geopandas.org/io.html
gdf = gpd.read_file('zip://'+str(data_path))
gdf = gdf[gdf.STATEFP=='13'].reset_index(drop=True)
gdf.GEOID = gdf.GEOID.apply(int)
gdf.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID       NAME LSAD  \
# 0      13      009  00345255  0500000US13009  13009    Baldwin   06
# 1      13      027  00345518  0500000US13027  13027     Brooks   06
# 2      13      103  00350219  0500000US13103  13103  Effingham   06
# 3      13      121  01694833  0500000US13121  13121     Fulton   06
# 4      13      141  00348209  0500000US13141  13141    Hancock   06
#
#         ALAND    AWATER                                           geometry
# 0   670027544  24802965  POLYGON ((-83.426739 33.182729, -83.42496 33.1...
# 1  1277108810  12188222  (POLYGON ((-83.33829 30.639723, -83.337079 30....
# 2  1240066122  10679265  POLYGON ((-81.548006 32.489286, -81.545503 32....
# 3  1364248547  19674940  POLYGON ((-84.849311 33.513184, -84.844286 33....
# 4  1220058034  17479744  POLYGON ((-83.27521999999999 33.191319, -83.27...

# %%
#
# Incidence Rates
#

# Load the data
project_dir = Path('/Users/merrelbook/Projects/HealthDataVizGA')
data_dir = project_dir / 'DataVisualAnalytics_Industries-cancer' / 'data_clean'
data_path = data_dir / 'county_cancer_stats' / 'incidencerates.csv'

df = pd.read_csv(data_path)

df = pd.read_csv(data_path)
df['GEOID'] = df['fips'].apply(int)

df[df.areatype=='county'].head()
# Out:
#                 locale     fips met_health_obj incidence rate_per_100000  \
# 2  Pickens County(7,8)  13227.0            ***                     580.8
# 3    Towns County(7,8)  13281.0            ***                     562.7
# 4    Union County(7,8)  13291.0            ***                     546.0
# 5      Lee County(7,8)  13177.0            ***                     542.6
# 6   Turner County(7,8)  13287.0            ***                     538.8
#
#   incidence rate_lower_95_confidence incidence rate_upper_95_confidence  \
# 2                              547.2                              616.1
# 3                              509.9                              620.5
# 4                              510.5                              583.9
# 5                              502.8                              584.7
# 6                              475.8                              608.2
#
#   annual_count_avg recent_trend_str trend_last_5  \
# 2            249.0           rising         1.2
# 3            116.0           stable         0.1
# 4            226.0           stable         0.4
# 5            154.0           stable         1.2
# 6             56.0           stable         0.3
#
#   trend_last_5_lower_95_confidence  ... cancer               file_name race  \
# 2                              0.2  ...      1  incidencerates_000.csv    0
# 3                             -1.1  ...      1  incidencerates_000.csv    0
# 4                             -0.7  ...      1  incidencerates_000.csv    0
# 5                              0.0  ...      1  incidencerates_000.csv    0
# 6                             -1.4  ...      1  incidencerates_000.csv    0
#
#    sex                                         source_url  stage  stateFIPS  \
# 2    0  https://www.statecancerprofiles.cancer.gov/inc...    NaN         13
# 3    0  https://www.statecancerprofiles.cancer.gov/inc...    NaN         13
# 4    0  https://www.statecancerprofiles.cancer.gov/inc...    NaN         13
# 5    0  https://www.statecancerprofiles.cancer.gov/inc...    NaN         13
# 6    0  https://www.statecancerprofiles.cancer.gov/inc...    NaN         13
#
#    type  late_stage_%  GEOID
# 2  incd           NaN  13227
# 3  incd           NaN  13281
# 4  incd           NaN  13291
# 5  incd           NaN  13177
# 6  incd           NaN  13287
#
# [5 rows x 23 columns]

# %%
joined = pd.merge(gdf, df, on='GEOID')

type(joined)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
joined
# Out:
#      STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID     NAME LSAD  \
# 0         13      009  00345255  0500000US13009  13009  Baldwin   06
# 1         13      009  00345255  0500000US13009  13009  Baldwin   06
# 2         13      009  00345255  0500000US13009  13009  Baldwin   06
# 3         13      009  00345255  0500000US13009  13009  Baldwin   06
# 4         13      009  00345255  0500000US13009  13009  Baldwin   06
# ...      ...      ...       ...             ...    ...      ...  ...
# 8740      13      039  01671316  0500000US13039  13039   Camden   06
# 8741      13      039  01671316  0500000US13039  13039   Camden   06
# 8742      13      039  01671316  0500000US13039  13039   Camden   06
# 8743      13      039  01671316  0500000US13039  13039   Camden   06
# 8744      13      039  01671316  0500000US13039  13039   Camden   06
#
#            ALAND     AWATER  \
# 0      670027544   24802965
# 1      670027544   24802965
# 2      670027544   24802965
# 3      670027544   24802965
# 4      670027544   24802965
# ...          ...        ...
# 8740  1632473254  392515252
# 8741  1632473254  392515252
# 8742  1632473254  392515252
# 8743  1632473254  392515252
# 8744  1632473254  392515252
#
#                                                geometry  ... areatype  cancer  \
# 0     POLYGON ((-83.426739 33.182729, -83.42496 33.1...  ...   county       1
# 1     POLYGON ((-83.426739 33.182729, -83.42496 33.1...  ...   county      71
# 2     POLYGON ((-83.426739 33.182729, -83.42496 33.1...  ...   county      76
# 3     POLYGON ((-83.426739 33.182729, -83.42496 33.1...  ...   county      55
# 4     POLYGON ((-83.426739 33.182729, -83.42496 33.1...  ...   county     400
# ...                                                 ...  ...      ...     ...
# 8740  POLYGON ((-81.93674899999999 31.060787, -81.93...  ...   county      40
# 8741  POLYGON ((-81.93674899999999 31.060787, -81.93...  ...   county      66
# 8742  POLYGON ((-81.93674899999999 31.060787, -81.93...  ...   county      18
# 8743  POLYGON ((-81.93674899999999 31.060787, -81.93...  ...   county      80
# 8744  POLYGON ((-81.93674899999999 31.060787, -81.93...  ...   county      58
#
#                    file_name race sex  \
# 0     incidencerates_000.csv    0   0
# 1     incidencerates_001.csv    0   0
# 2     incidencerates_002.csv    0   0
# 3     incidencerates_003.csv    0   2
# 4     incidencerates_004.csv    0   2
# ...                      ...  ...  ..
# 8740  incidencerates_054.csv    0   0
# 8741  incidencerates_055.csv    0   1
# 8742  incidencerates_056.csv    0   0
# 8743  incidencerates_057.csv    0   0
# 8744  incidencerates_058.csv    0   2
#
#                                              source_url  stage stateFIPS  \
# 0     https://www.statecancerprofiles.cancer.gov/inc...    NaN        13
# 1     https://www.statecancerprofiles.cancer.gov/inc...    NaN        13
# 2     https://www.statecancerprofiles.cancer.gov/inc...    NaN        13
# 3     https://www.statecancerprofiles.cancer.gov/inc...    NaN        13
# 4     https://www.statecancerprofiles.cancer.gov/inc...    NaN        13
# ...                                                 ...    ...       ...
# 8740  https://www.statecancerprofiles.cancer.gov/inc...  211.0        13
# 8741  https://www.statecancerprofiles.cancer.gov/inc...  211.0        13
# 8742  https://www.statecancerprofiles.cancer.gov/inc...  211.0        13
# 8743  https://www.statecancerprofiles.cancer.gov/inc...  211.0        13
# 8744  https://www.statecancerprofiles.cancer.gov/inc...  211.0        13
#
#       type late_stage_%
# 0     incd          NaN
# 1     incd          NaN
# 2     incd          NaN
# 3     incd          NaN
# 4     incd          NaN
# ...    ...          ...
# 8740  incd            *
# 8741  incd         15.6
# 8742  incd            *
# 8743  incd            *
# 8744  incd            *
#
# [8745 rows x 32 columns]

# %%
gdf.plot()
