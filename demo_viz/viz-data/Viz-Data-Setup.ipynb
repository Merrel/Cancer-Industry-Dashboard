# %%
# Importing package
import re
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../data_clean/indicators_per-industry_per-county.csv")
df
# Out:
#         Unnamed: 0   fips  county                    name industry_code  \
# 0                0   8001       1  Adams County, Colorado        113000
# 1                1   8001       1  Adams County, Colorado        115000
# 2                2   8001       1  Adams County, Colorado        211000
# 3                3   8001       1  Adams County, Colorado        2122a0
# 4                4   8001       1  Adams County, Colorado        212310
# ...            ...    ...     ...                     ...           ...
# 306027      306027  32510     510     Carson City, Nevada        812300
# 306028      306028  32510     510     Carson City, Nevada        812900
# 306029      306029  32510     510     Carson City, Nevada        813100
# 306030      306030  32510     510     Carson City, Nevada        813a00
# 306031      306031  32510     510     Carson City, Nevada        813b00
#
#                                           industry_detail  \
# ...

# %%
df_new = df.groupby(['fips', 'name', 'year'], as_index=False)['payann', 'estab', 
    'emp', 'ACID', 'ENRG', 'ETOX', 'EUTR', 'FOOD', 'GCC', 'HAPS', 'HAZW', 'HC', 
    'HNC', 'HRSP', 'HTOX', 'JOBS', 'LAND', 'METL', 'MINE', 'MSW', 'NREN',
       'OZON', 'PEST', 'REN', 'SMOG', 'VADD', 'WATR'].sum()
df_new
# Out:
#        fips                        name  year  payann  estab    emp  \
# 0      1001     Autauga County, Alabama  2012  128668    594   4954
# 1      1003     Baldwin County, Alabama  2012  953498   3340  32629
# 2      1005     Barbour County, Alabama  2012   53138    361   1715
# 3      1007        Bibb County, Alabama  2012   20778    205    655
# 4      1009      Blount County, Alabama  2012   61132    455   2161
# ...     ...                         ...   ...     ...    ...    ...
# 3135  56037  Sweetwater County, Wyoming  2012  491651    989   9029
# 3136  56039       Teton County, Wyoming  2012  361056   1402   8689
# 3137  56041       Uinta County, Wyoming  2012  145379    442   3287
# 3138  56043    Washakie County, Wyoming  2012   31951    283    907
# 3139  56045      Weston County, Wyoming  2012   19638    167    496
#
#             ACID          ENRG         ETOX        EUTR  ...      METL  \
# 0     299.152569  7.286445e+05  1963.026340   26.933851  ...  0.050200
# ...

# %%
df_cancer = pd.read_csv("../../data_clean/CDC_CancerByCounty/incidencerates.csv")
cancer_df = df_cancer[['fips', 'cancer']]  # 'trend_last_5' missing data in 10 counties
df_cancer=cancer_df.groupby(['fips'], as_index=False).sum()
df_cancer
# Out:
#          fips  cancer
# 0         0.0  172748
# 1      1000.0    3455
# 2      1001.0    3455
# 3      1003.0    3455
# 4      1005.0    3455
# ...       ...     ...
# 3185  56037.0    3455
# 3186  56039.0    3455
# 3187  56041.0    3455
# 3188  56043.0    3455
# 3189  56045.0    3455
#
# [3190 rows x 2 columns]

# %%
result = pd.merge(df_new, df_cancer, on='fips', how='inner')
result
# Out:
#        fips                        name  year  payann  estab    emp  \
# 0      1001     Autauga County, Alabama  2012  128668    594   4954
# 1      1003     Baldwin County, Alabama  2012  953498   3340  32629
# 2      1005     Barbour County, Alabama  2012   53138    361   1715
# 3      1007        Bibb County, Alabama  2012   20778    205    655
# 4      1009      Blount County, Alabama  2012   61132    455   2161
# ...     ...                         ...   ...     ...    ...    ...
# 3128  56037  Sweetwater County, Wyoming  2012  491651    989   9029
# 3129  56039       Teton County, Wyoming  2012  361056   1402   8689
# 3130  56041       Uinta County, Wyoming  2012  145379    442   3287
# 3131  56043    Washakie County, Wyoming  2012   31951    283    907
# 3132  56045      Weston County, Wyoming  2012   19638    167    496
#
#             ACID          ENRG         ETOX        EUTR  ...          MINE  \
# ...

# %%
result.to_csv("data_viz.csv", index=False)

# %%
df_new[~df_new.fips.isin(df_cancer.fips)]
# Out:
#        fips                                       name  year  payann  estab  \
# 76     2105          Hoonah-Angoon Census Area, Alaska  2012    2867     63
# 86     2195             Petersburg Census Area, Alaska  2012   14274    127
# 87     2198  Prince of Wales-Hyder Census Area, Alaska  2012    7959    108
# 89     2230               Skagway Municipality, Alaska  2012    9146     70
# 93     2275          Wrangell City and Borough, Alaska  2012    2974     56
# 2826  51019                   Bedford County, Virginia  2012  125055    888
# 2913  51515                     Bedford city, Virginia  2012   27819    269
#
#        emp       ACID         ENRG         ETOX       EUTR  ...      METL  \
# 76      48   1.109523     3.136368    46.491002   0.368733  ...  0.002392
# 86     265   1.566714     2.111854     0.097588  39.488054  ...  0.000074
# 87      64   1.449590     3.572667  1468.019312   0.695830  ...  0.000201
# ...

# %%
df[df['name'].str.contains('Ketchikan')]
# Out:
#        Unnamed: 0  fips  county                               name  \
# 91298       91298  2130     130  Ketchikan Gateway Borough, Alaska
# 91299       91299  2130     130  Ketchikan Gateway Borough, Alaska
# 91300       91300  2130     130  Ketchikan Gateway Borough, Alaska
# 91301       91301  2130     130  Ketchikan Gateway Borough, Alaska
# 91302       91302  2130     130  Ketchikan Gateway Borough, Alaska
# ...           ...   ...     ...                                ...
# 91378       91378  2130     130  Ketchikan Gateway Borough, Alaska
# 91379       91379  2130     130  Ketchikan Gateway Borough, Alaska
# 91380       91380  2130     130  Ketchikan Gateway Borough, Alaska
# 91381       91381  2130     130  Ketchikan Gateway Borough, Alaska
# 91382       91382  2130     130  Ketchikan Gateway Borough, Alaska
#
#       industry_code                                    industry_detail  \
# 91298        113000                     timber and raw forest products
# ...
